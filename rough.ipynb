# %%
# !pip install yfinance
# Out:
# ...
#   Obtaining dependency information for yfinance from https://files.pythonhosted.org/packages/a2/1d/1a35edd6943f27ff4b5e2d6ba634e7d1bac2e6f815f8efae0666ac71a68d/yfinance-0.2.46-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for multitasking>=0.0.7 from https://files.pythonhosted.org/packages/3e/8a/bb3160e76e844db9e69a413f055818969c8acade64e1a9ac5ce9dfdcf6c1/multitasking-0.0.11-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for frozendict>=2.3.4 from https://files.pythonhosted.org/packages/04/13/d9839089b900fa7b479cce495d62110cddc4bd5630a04d8469916c0e79c5/frozendict-2.4.6-py311-none-any.whl.metadata
# ...
#      ---------------------------------------- 0.0/939.5 kB ? eta -:--:--
#      ------ ------------------------------- 163.8/939.5 kB 4.8 MB/s eta 0:00:01
#      ------------------------------------- 939.5/939.5 kB 11.9 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
# ...

# %%
pd.set_option('display.max_rows', 100)

# %%
import pandas_datareader.data as web
import pandas as pd
import datetime as dt
import yfinance as yf

# %%
start = '2014'
end = dt.datetime(2017, 5, 24)
ticker = yf.Ticker('TRENT.NS')
data = ticker.history(period='2y', interval='1d')
data['Close']
# Out:
# Date
# 2022-11-09 00:00:00+05:30    1498.517212
# 2022-11-10 00:00:00+05:30    1467.733643
# 2022-11-11 00:00:00+05:30    1415.995117
# 2022-11-14 00:00:00+05:30    1423.977905
# 2022-11-15 00:00:00+05:30    1413.101440
#                                 ...
# 2024-11-04 00:00:00+05:30    7063.750000
# 2024-11-05 00:00:00+05:30    6968.350098
# 2024-11-06 00:00:00+05:30    6955.450195
# 2024-11-07 00:00:00+05:30    6505.500000
# 2024-11-08 00:00:00+05:30    6298.950195
# Name: Close, Length: 495, dtype: float64

# %%
data['wts'] = 1

# %%
data['Close'].tail(1).values[0]
# Out:
# 6968.35009765625

# %%
symbls = []
symbls.append(data['Open'].values)

# %%
sum(data['Open'])
# Out:
# 36424178.537109375

# %%
trent = yf.Ticker('TRENT.NS')

# %%
trent.info
# Out:
# {'address1': 'Trent House, G-Block',
#  'address2': 'Plot No. C-60, Beside Citibank Bandra Kurla Complex Bandra (East)',
#  'city': 'Mumbai',
#  'zip': '400051',
#  'country': 'India',
#  'phone': '91 22 6700 9000',
#  'fax': '91 22 6700 8100',
#  'website': 'https://trentlimited.com',
#  'industry': 'Apparel Retail',
#  'industryKey': 'apparel-retail',
#  'industryDisp': 'Apparel Retail',
#  'sector': 'Consumer Cyclical',
#  'sectorKey': 'consumer-cyclical',
#  'sectorDisp': 'Consumer Cyclical',
# ...

# %%
bs = trent.balance_sheet

# %%
bs.index
# Out:
# Index(['Ordinary Shares Number', 'Share Issued', 'Net Debt', 'Total Debt',
#        'Tangible Book Value', 'Invested Capital', 'Working Capital',
#        'Net Tangible Assets', 'Capital Lease Obligations',
#        'Common Stock Equity', 'Total Capitalization',
#        'Total Equity Gross Minority Interest', 'Minority Interest',
#        'Stockholders Equity', 'Other Equity Interest', 'Retained Earnings',
#        'Additional Paid In Capital', 'Capital Stock', 'Common Stock',
#        'Total Liabilities Net Minority Interest',
#        'Total Non Current Liabilities Net Minority Interest',
#        'Other Non Current Liabilities',
#        'Non Current Pension And Other Postretirement Benefit Plans',
#        'Tradeand Other Payables Non Current', 'Non Current Deferred Revenue',
#        'Non Current Deferred Taxes Liabilities',
#        'Long Term Debt And Capital Lease Obligation',
#        'Long Term Capital Lease Obligation', 'Long Term Debt',
# ...

# %%
income = trent.financials

# %%
income
# Out:
#                                                         2024-03-31  \
# Tax Effect Of Unusual Items                           1959158400.0
# Tax Rate For Calcs                                          0.2335
# Normalized EBITDA                                    20727300000.0
# Total Unusual Items                                   8390400000.0
# Total Unusual Items Excluding Goodwill                8390400000.0
# Net Income From Continuing Operation Net Minori...   14868000000.0
# Reconciled Depreciation                               6718400000.0
# Reconciled Cost Of Revenue                           69588900000.0
# EBITDA                                               29117700000.0
# EBIT                                                 22399300000.0
# Net Interest Income                                  -3491000000.0
# Interest Expense                                      3191000000.0
# Interest Income                                        185600000.0
# ...

# %%
bs
# Out:
#                                                        2024-03-31  \
# Ordinary Shares Number                                355487461.0
# Share Issued                                          355487461.0
# Net Debt                                             2040100000.0
# Total Debt                                          17529900000.0
# Tangible Book Value                                 39501700000.0
# Invested Capital                                    45663000000.0
# Working Capital                                     15683800000.0
# Net Tangible Assets                                 39501700000.0
# Capital Lease Obligations                           12544300000.0
# Common Stock Equity                                 40677400000.0
# Total Capitalization                                45663000000.0
# Total Equity Gross Minority Interest                41025900000.0
# Minority Interest                                     348500000.0
# ...

# %%
bs.loc['Total Assets'].iloc[0] - bs.loc['Total Liabilities Net Minority Interest'].iloc[0]
# Out:
# 41025900000.0

# %%
40677400000.0+348500000.0
# Out:
# 41025900000.0

# %%
import sqlite3
